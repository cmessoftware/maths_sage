# %%
# Algebra AbstractaTeoría y Aplicaciones
# Capitulo 2: Operaciones con enteros.

# %% [markdown]
# ![image.png](attachment:d1352196-370a-476d-9bf2-b09f0bdf6964.png)

# %%
r = 14 % 3
r
# Out:
# 2

# %%
q = (14 - r)/3
q
# Out:
# 4

# %% [markdown]
# También es posible obtener el cociente y el resto de forma simultánea con el método .quo_rem() (cociente y resto).

# %%
a = 14
b = 3
a.quo_rem(b)
# Out:
# (4, 2)

# %% [markdown]
# Un resto cero indica divisibilidad. Así (a % b) == 0 resulta True (verdadero) si
# b
#  divide a
# a
# ,
#  y de otro modo resultará False (falso).
#
#
# (20 % 5) == 0
# 1
# (20 % 5) == 0

# %%
(20 % 5) == 0
# Out:
# True

# %%
(17 % 4) == 0
# Out:
# False

# %% [markdown]
# El método .divides() es otra opción.

# %%
c = 3
c.divides(1615209895269251463267936926765382)
# Out:
# True

# %%
#Pruebo con numeros gigantes.
c = 7
a = 304551415520790006770067627138602243343847138471385047255154504920004230454504545923822238120418011173355
c.divides(a)
# Out:
# True

# %% [markdown]
# ### Máximo Común Divisor
# El máximo común divisor de
# a
#  y
# b
#  se obtiene con el comando gcd(a, b), donde por ahora,
# a
#  y
# b
#  son enteros. Más tarde,
# a
#  y
# b
#  podrán ser otros objetos con una noción de divisibilidad y “tamaño,” tales como los polinomios. Por ejemplo,

# %%
gcd(2776, 2452)
# Out:
# 4

# %%
gcd(400, 14)
# Out:
# 2

# %%
# Lo podemos usar para calcular si dos numeros son coprimos 
a = 31049
b = 2105
gcd(a, b) == 1
# Out:
# True

# %% [markdown]
# ![image.png](attachment:ce59955e-8fe3-4931-834c-8068f7077b17.png)

# %%
xgcd(633,331)
# Out:
# (1, -137, 262)

# %%
xgcd(400,14)
# Out:
# (2, 2, -57)

# %% [markdown]
# **Por el teorema de Bezout se puede represenar como un combinación lineal del tipo**
# $$
# \begin{aligned}
# ax+by &= d = \gcd(a,b) \\
# &\text{con } a,b,x,y \in \mathbb{N}.
# \end{aligned}
# $$

# %%
a = 400
b = 14
g,r,s = xgcd(a, b)
print(f'{g} = {r}*{a} + {s}*{b}')
# g = extended[0]
# r = extended[1]
# s = extended[2]
g == r*a + s*b
# Out:
# 2 = 2*400 + -57*14
# True

# %% [markdown]
# ## Primos y Factorización

# %%
a = 117371
a.is_prime()
# Out:
# True

# %%
a = 10000000006660000000001
a.is_prime()
# Out:
# False

# %%
a = random_prime(10^201, proof=True)
a
# Out:
# 643155427845230946083040816326973511601586605629561072489394340630843880898672201356877449870390900693383203373116598275287680802764855715067798713068770322310287049741205018861551596575772985043729069

# %%
prime_range(503, 550)
# Out:
# [503, 509, 521, 523, 541, 547]

# %%
prime_range(10000000006660000000001, 10000000006660000000001 + 1000)
# Out:
# [10000000006660000000007,
#  10000000006660000000021,
#  10000000006660000000057,
#  10000000006660000000171,
#  10000000006660000000187,
#  10000000006660000000231,
#  10000000006660000000243,
#  10000000006660000000309,
#  10000000006660000000333,
#  10000000006660000000501,
#  10000000006660000000579,
#  10000000006660000000603,
#  10000000006660000000621,
#  10000000006660000000673,
#  10000000006660000000723,
#  10000000006660000000739,
#  10000000006660000000799,
#  10000000006660000000837,
#  10000000006660000000933]

# %% [markdown]
# ## Factorización.

# %%
a = 2600
a.factor()
# Out:
# 2^3 * 5^2 * 13

# %%
a = 10000000006660000000007232132143245324230000000000000000001
a.factor()
# Out:
# 11 * 6883 * 68207 * 19167185286449 * 101028116505061163508432146542919039

# %%
a = 1000000000666000000000723213214324532423000000000000000000103
factored = a.factor()
first_term = factored[0]
first_term
# Out:
# (113, 1)

# %%
a = 28
factored = a.factor()
first_term = factored[0]
first_term
# Out:
# (2, 2)
